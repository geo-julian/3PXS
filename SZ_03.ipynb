# %%
import numpy as np
import pandas as pd
import sys


# db = pd.read_csv('append.csv', sep=',', header=0, \
#                  dtype={'SAMPLE_ID': object, 'ALT_Arg': object, 'ALT_Sil': object, 'MN_Min1_Style': object, 'MIN1': object, \
#                         'MN_MinOxState': object, 'MN_Ox1_Color': object, 'MN_Ox1_ColorMod': object, 'MN_Ox1_Gsize': object,\
#                         'MN_Sulfide_1': object, 'MN_Sulfide_1_Gsize': object, 'MN_Sulfide_1_Style': object, \
#                         'ST_Type': object, 'VN_Style': object, 'LTFORM':object, 'Formation':object}, \
#                  keep_default_na=True, na_filter=True, engine = 'python')

db = pd.read_csv('Nov_21_All_Rx_Samples.csv', sep=',', header=None, dtype=object, keep_default_na=False, na_filter=True, engine = 'python')
                 
print(db.shape)

db.columns = db.loc[0:4].fillna('').apply(' '.join).str.strip()
db = db.loc[5:].reset_index(drop=True)

print(db.shape)
print(list(db.columns.values))
# Out:
# (1517, 75)
# (1512, 75)
# ...

# %%
print(db.shape)
db.to_csv('Nov_23_All_Rx_Samples_1.csv', index=False, header=True)
# Out:
# (1512, 75)

# %%
print(list(db.columns.values))
# Out:
# ['Sample #', 'Date', 'Sampler', 'Easting', 'Northing', 'Zone/Area', 'Rock Type Code', 'Description', 'Analyte Symbol Unit Symbol Detection Limit Analysis Method', 'Au ppb ppb 5 FA-AA Anomalous', 'Au grav', 'Au PM', 'Li ppm 0.5 TD-MS', 'Na % 0.01 TD-MS', 'Mg % 0.01 TD-MS', 'Al % 0.01 TD-MS', 'K % 0.01 TD-MS', 'Ca % 0.01 TD-MS', 'Cd ppm 0.1 TD-MS', 'V ppm 1 TD-MS', 'Cr ppm 0.5 TD-MS', 'Mn ppm 1 TD-MS', 'Fe % 0.01 TD-MS', 'Hf ppm 0.1 TD-MS', 'Hg ppb 10 TD-MS', 'Ni ppm 0.5 TD-MS 100', 'Er ppm 0.1 TD-MS', 'Be ppm 0.1 TD-MS', 'Ho ppm 0.1 TD-MS', 'Ag ppm 0.05 TD-MS 2', 'Cs ppm 0.05 TD-MS', 'Co ppm 0.1 TD-MS 200', 'Eu ppm 0.05 TD-MS', 'Bi ppm 0.02 TD-MS', 'Se ppm 0.1 TD-MS', 'Zn ppm 0.2 TD-MS 200', 'Ga ppm 0.1 TD-MS', 'As ppm 0.1 TD-MS 45', 'Rb ppm 0.2 TD-MS', 'Y ppm 0.1 TD-MS', 'Sr ppm 0.2 TD-MS', 'Zr ppm 1 TD-MS', 'Nb ppm 0.1 TD-MS', 'Mo ppm 0.05 TD-MS 10', 'In ppm 0.1 TD-MS', 'Sn ppm 1 TD-MS', 'Sb ppm 0.1 TD-MS', 'Te ppm 0.1 TD-MS', 'Ba ppm 1 TD-MS', 'La ppm 0.1 TD-MS', 'Ce ppm 0.1 TD-MS'
# ...

# %%
db.columns = ['Sample#', 'Date', 'Sampler', 'Easting', 'Northing', 'Zone/Area', 'Rock_Type_Code', 
              'Description', 'Comment', 
              'Au_ppb', 'Au_ppm_grav', 'Au_ppm_PM', 
              'Li_ppm', 'Na_pct', 'Mg_pct', 
              'Al_pct', 'K_pct', 'Ca_pct', 'Cd_ppm', 'V_ppm', 'Cr_ppm', 
              'Mn ppm', 'Fe_pct', 'Hf_ppm', 'Hg_ppb', 'Ni_ppm', 'Er_ppm', 'Be_ppm', 
              'Ho_ppm', 'Ag_ppm', 'Cs_ppm', 'Co_ppm', 'Eu_ppm', 'Bi_ppm', 'Se_ppm', 
              'Zn_ppm', 'Ga_ppm', 'As_ppm', 'Rb_ppm', 'Y_ppm', 'Sr_ppm', 'Zr_ppm', 
              'Nb_ppm', 'Mo_ppm', 'In_ppm', 'Sn_ppm', 'Sb_ppm', 'Te_ppm', 'Ba_ppm', 
              'La_ppm', 'Ce_ppm', 'Pr_ppm', 'Nd_ppm', 'Sm_ppm', 'Gd_ppm', 'Tb_ppm', 
              'Dy_ppm', 'Cu_ppm', 'Ge_ppm', 'Tm_ppm', 'Yb_ppm', 'Lu_ppm', 'Ta_ppm', 
              'W_ppm', 'Re_ppm', 'Tl_ppm', 'Pb_ppm', 'Sc_ppm', 'Th_ppm', 'U_ppm', 
              'Ti_pct', 'P_pct', 'S_pct', 'Pt_unk', 'Pd_unk']

db.to_csv('Nov_23_All_Rx_Samples_1.csv', index=False, header=True)

# %%
db.Rock_Type_Code.unique()
# Out:
# array(['', '1aSH', '1a-sh-qv', '4c', '1a', 'QV', '4c-sh', '4c-sh-qv',
#        '1a-sh', 'qv', '2', '1ash-qv', '1b', '4alt', '3F/1A', '1A/3F',
#        '1A', '4ALT', '3A', '7A/6B', '3D', 'QV/3A', '6F', '5A/6F', '3A/QV',
#        '2E', '1ALT', '1ALT/QV', '4ALT/QV', '2E/QV', '1A/4B', '1H-1I', '3',
#        '1A/QV', '1A ', '4F', '3a', 'BIF-3a', '1a/3a?', '1alt', '3b',
#        '3a/BIF', '3d', '2b', '1a/qv', '6c', '4a', '4a-sh', '1alt-qv',
#        'qv-1alt', '4b', '4', '6b', '4E', '4B', '1B', '1alt-sh', 'qvs',
#        '4A', 'STD 215', 'BLANK', '1H', 'STD 216', '7A', 'STD 210',
#        '4B/4ALT', 'QTZ/3D', '1UT', '1alt-qvs', '1ALT/4ALT?', '1A/1alt?',
#        '4alt?', '1Alt', '1B/1ALT', 'QV/3D', '4b-QV', '3 or 2', 'qv-4b',
#        '1U?', '3G', '6C', '3g', '3alt', '8', '37', '4680', '145', '4780',
#        '4900', '85', '534', '161', '2210', '729', '57', '5b-qv', '3J',
#        '1alt-Qv', '3a-qv', '5b-alt', '5B', '6B', '6E', '5A'], dtype=object)

# %%
db['Field_Description'] = db['Rock_Type_Code']

db = db.replace({'Field_Description': {'':'Unknown', 
                               '1aSH':'Massive Flows', 
                               '1a-sh-qv':'Massive Flows/Quartz vein', 
                               '4c':'Quartz-Feldspar Porphyry', 
                               '1a':'Massive Flows', 
                               'QV':'Quartz vein', 
                               '4c-sh':'Quartz-Feldspar Porphyry', 
                               '4c-sh-qv':'Quartz-Feldspar Porphyry/Quartz vein',
       
                               '1a-sh':'Massive Flows', 
                               'qv':'Quartz vein', 
                               '2':'Unknown', 
                               '1ash-qv':'Massive Flows/Quartz vein', 
                               '1b':'Pillowed Flows', 
                               '4alt':'Altered Feldspar Porphyry', 
                               '3F/1A':'Sediment/Massive Flows', 
                               '1A/3F':'Sediment/Massive Flows',
       
                               '1A':'Massive Flows', 
                               '4ALT':'Altered Feldspar Porphyry', 
                               '3A':'Greywacke', 
                               '7A/6B':'Diabase/Gabbro', 
                               '3D':'Iron Formation', 
                               'QV/3A':'Quartz vein/Greywacke', 
                               '6F':'Mafic Dyke', 
                               '5A/6F':'Granite/Mafic Dyke', 
                               '3A/QV':'Greywacke/Quartz vein',
       
                               '2E':'Unknown', 
                               '1ALT':'Altered Mafic Volcanic', 
                               '1ALT/QV':'Altered Mafic Volcanic/Quartz vein', 
                               '4ALT/QV':'Altered Feldspar Porphyry/Quartz vein', 
                               '2E/QV':'Unknown/Quarz Vein', 
                               '1A/4B':'Massive Flows/Feldspar Porphyry', 
                               '1H-1I':'Mafic to Ultramafic Volcanics', 
                               '3':'Sediments',
       
                               '1A/QV':'Massive Flows/Quartz vein', 
                               '1A ':'Massive Flows', 
                               '4F':'Felsic Dyke', 
                               '3a':'Greywacke', 
                               'BIF-3a':'Greywacke/Iron Formation', 
                               '1a/3a?':'Massive Flows/Greywacke?', 
                               '1alt':'Altered Mafic Volcanic', 
                               '3b':'Argillite/Mudstone',
       
                               '3a/BIF':'Greywacke/Iron Formation', 
                               '3d':'Iron Formation', 
                               '2b':'Unknown', 
                               '1a/qv':'Massive Flows/Quartz vein', 
                               '6c':'Mafic Intrusives', 
                               '4a':'Quartz Porphyry', 
                               '4a-sh':'Quartz Porphyry', 
                               '1alt-qv':'Altered Mafic Volcanic/Quartz vein',
       
                               'qv-1alt':'Quartz vein/Altered Mafic Volcanics', 
                               '4b':'Feldspar Porphyry', 
                               '4':'Felsic Porphyritic Intrusive Rocks', 
                               '6b':'Gabbro', 
                               '4E':'Pegmatite', 
                               '4B':'Feldspar Porphyry', 
                               '1B':'Pillowed Flows', 
                               '1alt-sh':'Altered Mafic Volcanic', 
                               'qvs':'Quartz vein',
       
                               '4A':'Quartz Porphyry', 
                               'STD 215':'QAQC_STD', 
                               'BLANK':'QAQC_BLK', 
                               '1H':'Mafic to Ultramafic Volcanics', 
                               'STD 216':'QAQC_STD', 
                               '7A':'Diabase', 
                               'STD 210':'QAQC_STD',
       
                               '4B/4ALT':'Feldspar Porphyry/Altered', 
                               'QTZ/3D':'Quartz Stockwork/Iron Formation', 
                               '1UT':'Ultramafic Talc/Chlorite Altered', 
                               '1alt-qvs':'Altered Mafic Volcanic/Quartz vein', 
                               '1ALT/4ALT?':'Altered Mafic Volcanic/Altered Feldspar Porphyry', 
                               '1A/1alt?':'Massive Flows/altered?',
       
                               '4alt?':'Altered Feldspar Porphyry?', 
                               '1Alt':'Altered Mafic Volcanic', 
                               '1B/1ALT':'Pillowed Flows/Altered Mafic Volcanic', 
                               'QV/3D':'Quartz vein/Iron Formation', 
                               '4b-QV':'Feldspar Porphyry/Quartz vein', 
                               '3 or 2':'Sediments or Unknown?', 
                               'qv-4b':'Quartz vein/Feldspar porphyry',
       
                               '1U?':'Ultramafic?', 
                               '3G':'Sediments', 
                               '6C':'Mafic Intrusives', 
                               '3g':'Sediments', 
                               '3alt':'Altered Sediments', 
                               '8':'Unknown', 
                               '37':'Unknown', 
                               '4680':'Unknown', 
                               '145':'Unknown', 
                               '4780':'Unknown',
       
                               '4900':'Unknown', 
                               '85':'Unknown', 
                               '534':'Unknown', 
                               '161':'Unknown', 
                               '2210':'Unknown', 
                               '729':'Unknown', 
                               '57':'Unknown', 
                               '5b-qv':'Granodiorite/Quartz vein', 
                               '3J':'Sediments',
       
                               '1alt-Qv':'Altered Mafic Volcanic/Quartz vein', 
                               '3a-qv':'Greywacke/Quartz vein', 
                               '5b-alt':'Granodiorite/Altered', 
                               '5B':'Granodiorite', 
                               '6B':'Gabbro', 
                               '6E':'Mafic Intrusives', 
                               '5A': 'Granite'}})

db.Field_Description.unique()
# Out:
# array(['Unknown', 'Massive Flows', 'Massive Flows/Quartz vein',
#        'Quartz-Feldspar Porphyry', 'Quartz vein',
#        'Quartz-Feldspar Porphyry/Quartz vein', 'Pillowed Flows',
#        'Altered Feldspar Porphyry', 'Sediment/Massive Flows', 'Greywacke',
#        'Diabase/Gabbro', 'Iron Formation', 'Quartz vein/Greywacke',
#        'Mafic Dyke', 'Granite/Mafic Dyke', 'Greywacke/Quartz vein',
#        'Altered Mafic Volcanic', 'Altered Mafic Volcanic/Quartz vein',
#        'Altered Feldspar Porphyry/Quartz vein', 'Unknown/Quarz Vein',
#        'Massive Flows/Feldspar Porphyry', 'Mafic to Ultramafic Volcanics',
#        'Sediments', 'Felsic Dyke', 'Greywacke/Iron Formation',
#        'Massive Flows/Greywacke?', 'Argillite/Mudstone',
#        'Mafic Intrusives', 'Quartz Porphyry',
#        'Quartz vein/Altered Mafic Volcanics', 'Feldspar Porphyry',
#        'Felsic Porphyritic Intrusive Rocks', 'Gabbro', 'Pegmatite',
# ...

# %%
#db.to_csv('Nov_23_All_Rx_Samples_1.csv', index=False, header=True)

# %%
db['Litho_group'] = db['Field_Description']

db = db.replace({'Litho_group': {'Massive Flows':'Mafic to Ultramafic Volcanics', 
                                 'Massive Flows/Quartz vein':'Mafic to Ultramafic Volcanics',
                                 'Quartz-Feldspar Porphyry':'Felsic Intrusives', 
                                 'Quartz vein':'Unknown',
                                 'Quartz-Feldspar Porphyry/Quartz vein':'Felsic Intrusives', 
                                 'Pillowed Flows':'Mafic to Ultramafic Volcanics',
                                 'Altered Feldspar Porphyry':'Felsic Intrusives', 
                                 'Sediment/Massive Flows':'Sediments/Mafic to Ultramafic Volcanics', 
                                 'Greywacke':'Sediments',
                                 'Diabase/Gabbro':'Mafic Intrusives', 
                                 'Iron Formation':'Sediments', 
                                 'Quartz vein/Greywacke':'Sediments',
                                 'Mafic Dyke':'Mafic Intrusives', 
                                 'Granite/Mafic Dyke':'Felsic Intrusives', 
                                 'Greywacke/Quartz vein':'Sediments',
                                 'Altered Mafic Volcanic':'Mafic to Ultramafic Volcanics', 
                                 'Altered Mafic Volcanic/Quartz vein':'Mafic to Ultramafic Volcanics',
                                 'Altered Feldspar Porphyry/Quartz vein':'Felsic Intrusives', 
                                 'Unknown/Quarz Vein':'Unknown',
                                 'Massive Flows/Feldspar Porphyry':'Mafic to Ultramafic Volcanics/Felsic Intrusives', 
                                 'Mafic to Ultramafic Volcanics':'Mafic to Ultramafic Volcanics',
                                 'Sediments':'Sediments', 
                                 'Felsic Dyke':'Felsic Intrusives', 
                                 'Greywacke/Iron Formation':'Sediments',
                                 'Massive Flows/Greywacke?':'Mafic to Ultramafic Volcanics/Sediments?', 
                                 'Argillite/Mudstone':'Sediments',
                                 'Mafic Intrusives':'Mafic Intrusives', 
                                 'Quartz Porphyry':'Felsic Intrusives',
                                 'Quartz vein/Altered Mafic Volcanics':'Mafic to Ultramafic Volcanics', 
                                 'Feldspar Porphyry':'Felsic Intrusives',
                                 'Felsic Porphyritic Intrusive Rocks':'Felsic Intrusives', 
                                 'Gabbro':'Mafic Intrusives', 
                                 'Pegmatite':'Felsic Intrusives',
                                 'QAQC_STD':'QAQC', 
                                 'QAQC_BLK':'QAQC', 
                                 'Diabase':'Mafic Intrusives', 
                                 'Feldspar Porphyry/Altered':'Felsic Intrusives',
                                 'Quartz Stockwork/Iron Formation':'Sediments',
                                 'Ultramafic Talc/Chlorite Altered':'Mafic to Ultramafic Volcanics',
                                 'Altered Mafic Volcanic/Altered Feldspar Porphyry':'Mafic to Ultramafic Volcanics/Felsic Intrusives',
                                 'Massive Flows/altered?':'Mafic to Ultramafic Volcanics', 
                                 'Altered Feldspar Porphyry?':'Felsic Intrusives',
                                 'Pillowed Flows/Altered Mafic Volcanic':'Mafic to Ultramafic Volcanics',
                                 'Quartz vein/Iron Formation':'Sediments', 
                                 'Feldspar Porphyry/Quartz vein':'Felsic Intrusives',
                                 'Sediments or Unknown?':'Sediments', 
                                 'Quartz vein/Feldspar porphyry':'Felsic Intrusives',
                                 'Ultramafic?':'Mafic to Ultramafic Volcanics', 
                                 'Altered Sediments':'Sediments', 
                                 'Granodiorite/Quartz vein':'Felsic Intrusives',
                                 'Granodiorite/Altered':'Felsic Intrusives', 
                                 'Granodiorite':'Felsic Intrusives', 
                                 'Granite':'Felsic Intrusives'}})

db.Litho_group.unique()


db['Alteration'] = db['Field_Description']

db = db.replace({'Alteration': {'Massive Flows':'Unaltered', 
                                 'Massive Flows/Quartz vein':'Unaltered',
                                 'Quartz-Feldspar Porphyry':'Unaltered', 
                                 'Quartz vein':'Unaltered',
                                 'Quartz-Feldspar Porphyry/Quartz vein':'Unaltered', 
                                 'Pillowed Flows':'Unaltered',
                                 'Altered Feldspar Porphyry':'Altered', 
                                 'Sediment/Massive Flows':'Unaltered', 
                                 'Greywacke':'Unaltered',
                                 'Diabase/Gabbro':'Unaltered', 
                                 'Iron Formation':'Unaltered', 
                                 'Quartz vein/Greywacke':'Unaltered',
                                 'Mafic Dyke':'Unaltered', 
                                 'Granite/Mafic Dyke':'Unaltered', 
                                 'Greywacke/Quartz vein':'Unaltered',
                                 'Altered Mafic Volcanic':'Altered', 
                                 'Altered Mafic Volcanic/Quartz vein':'Altered',
                                 'Altered Feldspar Porphyry/Quartz vein':'Altered', 
                                 'Unknown/Quarz Vein':'Unaltered',
                                 'Massive Flows/Feldspar Porphyry':'Unaltered', 
                                 'Mafic to Ultramafic Volcanics':'Unaltered',
                                 'Sediments':'Unaltered', 
                                 'Felsic Dyke':'Unaltered', 
                                 'Greywacke/Iron Formation':'Unaltered',
                                 'Massive Flows/Greywacke?':'Unaltered', 
                                 'Argillite/Mudstone':'Unaltered',
                                 'Mafic Intrusives':'Unaltered', 
                                 'Quartz Porphyry':'Unaltered',
                                 'Quartz vein/Altered Mafic Volcanics':'Altered', 
                                 'Feldspar Porphyry':'Unaltered',
                                 'Felsic Porphyritic Intrusive Rocks':'Unaltered', 
                                 'Gabbro':'Unaltered', 
                                 'Pegmatite':'Unaltered',
                                 'QAQC_STD':'Unknown', 
                                 'QAQC_BLK':'Unknown', 
                                 'Diabase':'Unaltered', 
                                 'Feldspar Porphyry/Altered':'Altered',
                                 'Quartz Stockwork/Iron Formation':'Unaltered',
                                 'Ultramafic Talc/Chlorite Altered':'Altered',
                                 'Altered Mafic Volcanic/Altered Feldspar Porphyry':'Altered',
                                 'Massive Flows/altered?':'Altered', 
                                 'Altered Feldspar Porphyry?':'Altered',
                                 'Pillowed Flows/Altered Mafic Volcanic':'Altered',
                                 'Quartz vein/Iron Formation':'Unaltered', 
                                 'Feldspar Porphyry/Quartz vein':'Unaltered',
                                 'Sediments or Unknown?':'Unaltered', 
                                 'Quartz vein/Feldspar porphyry':'Unaltered',
                                 'Ultramafic?':'Unaltered', 
                                 'Altered Sediments':'Altered', 
                                 'Granodiorite/Quartz vein':'Unaltered',
                                 'Granodiorite/Altered':'Altered', 
                                 'Granodiorite':'Unaltered', 
                                 'Granite':'Unaltered'}})

db.Alteration.unique()



db['Structures'] = db['Field_Description']

db = db.replace({'Structures': {'Massive Flows':'Not Reported', 
                                 'Massive Flows/Quartz vein':'Quartz vein',
                                 'Quartz-Feldspar Porphyry':'Not Reported', 
                                 'Quartz vein':'Quartz vein',
                                 'Quartz-Feldspar Porphyry/Quartz vein':'Quartz vein', 
                                 'Pillowed Flows':'Not Reported',
                                 'Altered Feldspar Porphyry':'Not Reported', 
                                 'Sediment/Massive Flows':'Not Reported', 
                                 'Greywacke':'Not Reported',
                                 'Diabase/Gabbro':'Not Reported', 
                                 'Iron Formation':'Not Reported', 
                                 'Quartz vein/Greywacke':'Quartz vein',
                                 'Mafic Dyke':'Not Reported', 
                                 'Granite/Mafic Dyke':'Not Reported', 
                                 'Greywacke/Quartz vein':'Quartz vein',
                                 'Altered Mafic Volcanic':'Not Reported', 
                                 'Altered Mafic Volcanic/Quartz vein':'Quartz vein',
                                 'Altered Feldspar Porphyry/Quartz vein':'Quartz vein', 
                                 'Unknown/Quarz Vein':'Quartz vein',
                                 'Massive Flows/Feldspar Porphyry':'Not Reported', 
                                 'Mafic to Ultramafic Volcanics':'Not Reported',
                                 'Sediments':'Not Reported', 
                                 'Felsic Dyke':'Not Reported', 
                                 'Greywacke/Iron Formation':'Not Reported',
                                 'Massive Flows/Greywacke?':'Not Reported', 
                                 'Argillite/Mudstone':'Not Reported',
                                 'Mafic Intrusives':'Not Reported', 
                                 'Quartz Porphyry':'Not Reported',
                                 'Quartz vein/Altered Mafic Volcanics':'Quartz vein', 
                                 'Feldspar Porphyry':'Not Reported',
                                 'Felsic Porphyritic Intrusive Rocks':'Not Reported', 
                                 'Gabbro':'Not Reported', 
                                 'Pegmatite':'Not Reported',
                                 'QAQC_STD':'Not Reported', 
                                 'QAQC_BLK':'Not Reported', 
                                 'Diabase':'Not Reported', 
                                 'Feldspar Porphyry/Altered':'Not Reported',
                                 'Quartz Stockwork/Iron Formation':'Quartz stockwork',
                                 'Ultramafic Talc/Chlorite Altered':'Not Reported',
                                 'Altered Mafic Volcanic/Altered Feldspar Porphyry':'Not Reported',
                                 'Massive Flows/altered?':'Not Reported', 
                                 'Altered Feldspar Porphyry?':'Not Reported',
                                 'Pillowed Flows/Altered Mafic Volcanic':'Not Reported',
                                 'Quartz vein/Iron Formation':'Quartz vein', 
                                 'Feldspar Porphyry/Quartz vein':'Quartz vein',
                                 'Sediments or Unknown?':'Not Reported', 
                                 'Quartz vein/Feldspar porphyry':'Quartz vein',
                                 'Ultramafic?':'Not Reported', 
                                 'Altered Sediments':'Not Reported', 
                                 'Granodiorite/Quartz vein':'Quartz vein',
                                 'Granodiorite/Altered':'Not Reported', 
                                 'Granodiorite':'Not Reported', 
                                 'Granite':'Not Reported'}})

db.Structures.unique()
# Out:
# array(['Unknown', 'Not Reported', 'Quartz vein', 'Quartz stockwork'],
#       dtype=object)

# %%
print(list(db.columns.values))
# Out:
# ['Sample#', 'Date', 'Sampler', 'Easting', 'Northing', 'Zone/Area', 'Rock_Type_Code', 'Description', 'Comment', 'Au_ppb', 'Au_ppm_grav', 'Au_ppm_PM', 'Li_ppm', 'Na_pct', 'Mg_pct', 'Al_pct', 'K_pct', 'Ca_pct', 'Cd_ppm', 'V_ppm', 'Cr_ppm', 'Mn ppm', 'Fe_pct', 'Hf_ppm', 'Hg_ppb', 'Ni_ppm', 'Er_ppm', 'Be_ppm', 'Ho_ppm', 'Ag_ppm', 'Cs_ppm', 'Co_ppm', 'Eu_ppm', 'Bi_ppm', 'Se_ppm', 'Zn_ppm', 'Ga_ppm', 'As_ppm', 'Rb_ppm', 'Y_ppm', 'Sr_ppm', 'Zr_ppm', 'Nb_ppm', 'Mo_ppm', 'In_ppm', 'Sn_ppm', 'Sb_ppm', 'Te_ppm', 'Ba_ppm', 'La_ppm', 'Ce_ppm', 'Pr_ppm', 'Nd_ppm', 'Sm_ppm', 'Gd_ppm', 'Tb_ppm', 'Dy_ppm', 'Cu_ppm', 'Ge_ppm', 'Tm_ppm', 'Yb_ppm', 'Lu_ppm', 'Ta_ppm', 'W_ppm', 'Re_ppm', 'Tl_ppm', 'Pb_ppm', 'Sc_ppm', 'Th_ppm', 'U_ppm', 'Ti_pct', 'P_pct', 'S_pct', 'Pt_unk', 'Pd_unk', 'Field_Description', 'Litho_group', 'Alteration', 'Structures']

# %%
db = db[['Sample#', 'Date', 'Sampler', 'Easting', 'Northing', 'Zone/Area', 
         'Rock_Type_Code', 'Field_Description', 'Litho_group', 'Alteration', 'Structures',
         'Au_ppb', 'Au_ppm_grav', 'Au_ppm_PM', 'Li_ppm', 'Na_pct', 'Mg_pct', 'Al_pct', 'K_pct', 
         'Ca_pct', 'Cd_ppm', 'V_ppm', 'Cr_ppm', 'Mn ppm', 'Fe_pct', 'Hf_ppm', 'Hg_ppb', 'Ni_ppm', 
         'Er_ppm', 'Be_ppm', 'Ho_ppm', 'Ag_ppm', 'Cs_ppm', 'Co_ppm', 'Eu_ppm', 'Bi_ppm', 'Se_ppm', 
         'Zn_ppm', 'Ga_ppm', 'As_ppm', 'Rb_ppm', 'Y_ppm', 'Sr_ppm', 'Zr_ppm', 'Nb_ppm', 'Mo_ppm', 
         'In_ppm', 'Sn_ppm', 'Sb_ppm', 'Te_ppm', 'Ba_ppm', 'La_ppm', 'Ce_ppm', 'Pr_ppm', 'Nd_ppm', 
         'Sm_ppm', 'Gd_ppm', 'Tb_ppm', 'Dy_ppm', 'Cu_ppm', 'Ge_ppm', 'Tm_ppm', 'Yb_ppm', 'Lu_ppm', 
         'Ta_ppm', 'W_ppm', 'Re_ppm', 'Tl_ppm', 'Pb_ppm', 'Sc_ppm', 'Th_ppm', 'U_ppm', 'Ti_pct', 
         'P_pct', 'S_pct', 'Pt_unk', 'Pd_unk', 'Description', 'Comment']]

# %%
#db.to_csv('Nov_23_All_Rx_Samples_1.csv', index=False, header=True)

# %%
db_data = db[db.Litho_group != 'QAQC']
db_data.to_csv('Nov_23_Data_Rx_Samples_1.csv', index=False, header=True)

db_std = db[db.Field_Description == 'QAQC_STD']
db_std.to_csv('Nov_23_STD_Rx_Samples_1.csv', index=False, header=True)

db_blk = db[db.Field_Description == 'QAQC_BLK']
db_blk.to_csv('Nov_23_BLK_Rx_Samples_1.csv', index=False, header=True)
